# %%
import numpy as np
import pandas as pd
import seaborn as sns
import matplotlib.pyplot as plt

# %matplotlib inline

# %%
df = pd.read_csv('Summary_of_Weather.csv',  low_memory=False)

# %%
df.head()
# Out:
#      STA      Date Precip  WindGustSpd    MaxTemp    MinTemp   MeanTemp  \
# 0  10001  1942-7-1  1.016          NaN  25.555556  22.222222  23.888889
# 1  10001  1942-7-2      0          NaN  28.888889  21.666667  25.555556
# 2  10001  1942-7-3   2.54          NaN  26.111111  22.222222  24.444444
# 3  10001  1942-7-4   2.54          NaN  26.666667  22.222222  24.444444
# 4  10001  1942-7-5      0          NaN  26.666667  21.666667  24.444444
#
#   Snowfall PoorWeather  YR  ...  FB  FTI ITH  PGT  TSHDSBRSGF  SD3  RHX  RHN  \
# 0        0         NaN  42  ... NaN  NaN NaN  NaN         NaN  NaN  NaN  NaN
# 1        0         NaN  42  ... NaN  NaN NaN  NaN         NaN  NaN  NaN  NaN
# 2        0         NaN  42  ... NaN  NaN NaN  NaN         NaN  NaN  NaN  NaN
# 3        0         NaN  42  ... NaN  NaN NaN  NaN         NaN  NaN  NaN  NaN
# 4        0         NaN  42  ... NaN  NaN NaN  NaN         NaN  NaN  NaN  NaN
#
#   RVG  WTE
# 0 NaN  NaN
# 1 NaN  NaN
# 2 NaN  NaN
# 3 NaN  NaN
# ...

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 119040 entries, 0 to 119039
# Data columns (total 31 columns):
#  #   Column       Non-Null Count   Dtype
# ---  ------       --------------   -----
#  0   STA          119040 non-null  int64
#  1   Date         119040 non-null  object
#  2   Precip       119040 non-null  object
#  3   WindGustSpd  532 non-null     float64
#  4   MaxTemp      119040 non-null  float64
#  5   MinTemp      119040 non-null  float64
#  6   MeanTemp     119040 non-null  float64
#  7   Snowfall     117877 non-null  object
#  8   PoorWeather  34237 non-null   object
#  9   YR           119040 non-null  int64
#  10  MO           119040 non-null  int64
#  11  DA           119040 non-null  int64
#  12  PRCP         117108 non-null  object
#  13  DR           533 non-null     float64
#  14  SPD          532 non-null     float64
#  15  MAX          118566 non-null  float64
#  16  MIN          118572 non-null  float64
#  17  MEA          118542 non-null  float64
# ...

# %%
df.describe()
# Out:
#                  STA  WindGustSpd        MaxTemp        MinTemp  \
# count  119040.000000   532.000000  119040.000000  119040.000000
# mean    29659.435795    37.774534      27.045111      17.789511
# std     20953.209402    10.297808       8.717817       8.334572
# min     10001.000000    18.520000     -33.333333     -38.333333
# 25%     11801.000000    29.632000      25.555556      15.000000
# 50%     22508.000000    37.040000      29.444444      21.111111
# 75%     33501.000000    43.059000      31.666667      23.333333
# max     82506.000000    75.932000      50.000000      34.444444
#
#             MeanTemp             YR             MO             DA          DR  \
# count  119040.000000  119040.000000  119040.000000  119040.000000  533.000000
# mean       22.411631      43.805284       6.726016      15.797530   26.998124
# std         8.297982       1.136718       3.425561       8.794541   15.221732
# ...

# %%
plt.figure(figsize=(12,7))
sns.heatmap(df.isnull())
plt.show()

# %%
cleaning_data = df.drop(['DR','SPD','SND','FT','FB','FTI','ITH','PGT','SD3','RHX','RHN','RVG','WTE','WindGustSpd','PoorWeather','TSHDSBRSGF'], axis = 1)

# %%
cleaning_data
# Out:
#           STA        Date Precip    MaxTemp    MinTemp   MeanTemp Snowfall  \
# 0       10001    1942-7-1  1.016  25.555556  22.222222  23.888889        0
# 1       10001    1942-7-2      0  28.888889  21.666667  25.555556        0
# 2       10001    1942-7-3   2.54  26.111111  22.222222  24.444444        0
# 3       10001    1942-7-4   2.54  26.666667  22.222222  24.444444        0
# 4       10001    1942-7-5      0  26.666667  21.666667  24.444444        0
# ...       ...         ...    ...        ...        ...        ...      ...
# 119035  82506  1945-12-27      0  28.333333  18.333333  23.333333        0
# 119036  82506  1945-12-28  9.906  29.444444  18.333333  23.888889        0
# 119037  82506  1945-12-29      0  28.333333  18.333333  23.333333        0
# 119038  82506  1945-12-30      0  28.333333  18.333333  23.333333        0
# 119039  82506  1945-12-31      0  29.444444  17.222222  23.333333        0
#
#         YR  MO  DA  PRCP   MAX   MIN   MEA SNF
# ...

# %%
percent_missing = cleaning_data.isnull().sum()* 100/ len(df)
missing_value_df = pd.DataFrame({'column_name': cleaning_data.columns,
                                 'percent_missing': percent_missing})

# %% [markdown]
# cleaning_data.isnull().sum()*100/len(df)  calculates the percentage of null values (data cleaning)

# %%
percent_missing
missing_value_df
# Out:
#          column_name  percent_missing
# STA              STA         0.000000
# Date            Date         0.000000
# Precip        Precip         0.000000
# MaxTemp      MaxTemp         0.000000
# MinTemp      MinTemp         0.000000
# MeanTemp    MeanTemp         0.000000
# Snowfall    Snowfall         0.976983
# YR                YR         0.000000
# MO                MO         0.000000
# DA                DA         0.000000
# PRCP            PRCP         1.622984
# MAX              MAX         0.398185
# MIN              MIN         0.393145
# MEA              MEA         0.418347
# SNF              SNF         0.976983

# %%
plt.figure(figsize=(12,7))
sns.heatmap(cleaning_data.isnull())
plt.show()

# %%
cleaning_data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 119040 entries, 0 to 119039
# Data columns (total 15 columns):
#  #   Column    Non-Null Count   Dtype
# ---  ------    --------------   -----
#  0   STA       119040 non-null  int64
#  1   Date      119040 non-null  object
#  2   Precip    119040 non-null  object
#  3   MaxTemp   119040 non-null  float64
#  4   MinTemp   119040 non-null  float64
#  5   MeanTemp  119040 non-null  float64
#  6   Snowfall  117877 non-null  object
#  7   YR        119040 non-null  int64
#  8   MO        119040 non-null  int64
#  9   DA        119040 non-null  int64
#  10  PRCP      117108 non-null  object
#  11  MAX       118566 non-null  float64
#  12  MIN       118572 non-null  float64
#  13  MEA       118542 non-null  float64
#  14  SNF       117877 non-null  object
# dtypes: float64(6), int64(4), object(5)
# memory usage: 13.6+ MB

# %%
clean = cleaning_data.isnull()

# %%
# clean.to_csv('cleandata.csv')

# %%
clean_data = cleaning_data.fillna(df.mean())
# Out:
# C:\Users\Saket\AppData\Local\Temp\ipykernel_23340\1126011225.py:1: FutureWarning: Dropping of nuisance columns in DataFrame reductions (with 'numeric_only=None') is deprecated; in a future version this will raise TypeError.  Select only valid columns before calling the reduction.
#   clean_data = cleaning_data.fillna(df.mean())

# %%
for clmn in clean_data.columns[clean_data.isnull().sum() > 0]:
    try:
        clean_data = clean_data[(clean_data[clmn].str.contains("T") == False)]
    except:
        None

# %%
plt.figure(figsize=(12,7))
sns.heatmap(clean.isnull())
# sns.heatmap(clean.isnull())
plt.show()

# %%
clean.isnull().sum().sum()
# Out:
# 0

# %%
plt.figure(figsize=(16,9))
plt.suptitle('Boxplot of the all the columns of DF')

for i, clnm in enumerate(['MaxTemp', 'MinTemp','MeanTemp']):
    plt.subplot(2,2,i+1)
    plt.boxplot(df[clnm])
    plt.title(clnm)

# %%
from sklearn import linear_model

# %%
clean_data.drop(['Date','YR','MO','DA'], axis = 'columns',inplace = True)

# %%
clean_data
# Out:
#           STA Precip    MaxTemp    MinTemp   MeanTemp Snowfall  PRCP   MAX  \
# 0       10001  1.016  25.555556  22.222222  23.888889        0  0.04  78.0
# 1       10001      0  28.888889  21.666667  25.555556        0     0  84.0
# 2       10001   2.54  26.111111  22.222222  24.444444        0   0.1  79.0
# 3       10001   2.54  26.666667  22.222222  24.444444        0   0.1  80.0
# 4       10001      0  26.666667  21.666667  24.444444        0     0  80.0
# ...       ...    ...        ...        ...        ...      ...   ...   ...
# 119035  82506      0  28.333333  18.333333  23.333333        0     0  83.0
# 119036  82506  9.906  29.444444  18.333333  23.888889        0  0.39  85.0
# 119037  82506      0  28.333333  18.333333  23.333333        0     0  83.0
# 119038  82506      0  28.333333  18.333333  23.333333        0     0  83.0
# 119039  82506      0  29.444444  17.222222  23.333333        0     0  85.0
#
#          MIN   MEA SNF
# 0       72.0  75.0   0
# ...

# %%
corr = clean_data.corr()
sns.heatmap(corr,annot = True)
# Out:
# <AxesSubplot:>

# %%
# X = clean_data.drop(['MaxTemp','MinTemp','MeanTemp'], axis = 'columns')
X = clean_data.drop(['MaxTemp','MinTemp','MeanTemp'], axis = 'columns')

# %%
Y = clean_data['MaxTemp']

# %%
from sklearn.model_selection import train_test_split

# %%
X_train, X_test , y_train, y_test = train_test_split(X,Y,train_size=0.8)

# %%
from sklearn.linear_model import LinearRegression

# %%
model = LinearRegression()

# %%
model.fit(X_train,y_train)
# Out:
# LinearRegression()

# %%
y_predict = model.predict(X_test)

# %%
model.score(X_test,y_test)*100
# Out:
# 87.51150318681482

# %%
from sklearn import datasets, linear_model
from sklearn.metrics import mean_squared_error, r2_score

# %%
# plt.scatter(X_test, y_test, color="black")
plt.plot(np.arange(len(y_test)), y_test, color="blue", linewidth=3)
plt.plot(np.arange(len(y_predict)), y_predict, color="green", linewidth=3)
plt.xticks(())
plt.yticks(())
plt.show()
